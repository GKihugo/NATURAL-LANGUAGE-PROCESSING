# %%
import os
import nltk
import nltk.corpus

# %%
print(os.listdir(nltk.data.find("corpora.zip")))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-a4f52ca51bf6> in <module>
# ----> 1 print(os.listdir(nltk.data.find("corpora.zip")))
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     676
#     677     # Identify the package (i.e. the .zip file) to download.
# --> 678     resource_zipname = resource_name.split('/')[1]
#     679     if resource_zipname.endswith('.zip'):
#     680         resource_zipname = resource_zipname.rpartition('.')[0]
#
# IndexError: list index out of range

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      85                 try:
# ---> 86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#
# LookupError:
# **********************************************************************
#   Resource gutenberg not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('gutenberg')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/gutenberg.zip/gutenberg/
#
#   Searched in:
# ...

# %%
a=nltk.corpus.gutenberg.words('shakespeare_hamlet.txt')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      85                 try:
# ---> 86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#
# LookupError:
# **********************************************************************
#   Resource gutenberg not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('gutenberg')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/gutenberg.zip/gutenberg/
#
#   Searched in:
# ...

# %%
me="Special skill oficiency Microsoft office packages: Ms excel, Ms words, Ms access ,Power point  ,internet ,Database Management and user support applications example Active Directory, Microsoft Navigation Proficiency in mathematics related applications: applied mathematics in fluid dynamics and mechanics, research and statistical mathematics and financial accounting. I also have dynamics Knowledge in Applied MathematicsProficiency in Programming languages C++, Java and Python  HTML, CSS, PHP, Bootstrap and java Script Proficiency in Data Science and Machine Learning. Handling of data in libraries such as Pandas, Jupiter note Books, R, Matlab and resourceful data training libraries  Leadership "

# %%
from nltk.tokenize import word_tokenize

# %%
me_tokens=word_tokenize(me)
me_tokens
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-45-e94ba7937e11> in <module>
# ----> 1 me_tokens=word_tokenize(me)
#       2 me_tokens
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     142     :type preserve_line: bool
#     143     """
# --> 144     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     145     return [
#     146         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#     103     :param language: the model name in the Punkt corpus
#     104     """
# --> 105     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
#     106     return tokenizer.tokenize(text)
#     107
#
# ...

# %%
from nltk.util import bigrams,trigrams,ngrams

# %%
Sting="I love George"

# %%
quotes=nltk.word_tokenize(Sting)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-50-2150fcbddbdf> in <module>
# ----> 1 quotes=nltk.word_tokenize(Sting)
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     142     :type preserve_line: bool
#     143     """
# --> 144     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     145     return [
#     146         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#     103     :param language: the model name in the Punkt corpus
#     104     """
# --> 105     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
#     106     return tokenizer.tokenize(text)
#     107
#
# ...

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      85                 try:
# ---> 86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
# ...
